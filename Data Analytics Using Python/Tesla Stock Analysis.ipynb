# %%
# !pip install pandas-datareader 
# !pip install yfinance
import pandas_datareader as pdr
import pandas as pd
import yfinance as yfin

from datetime import datetime
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\kunal kakara\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas-datareader) (1.4.4)
# Requirement already satisfied: lxml in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\kunal kakara\anaconda3\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pytz>=2022.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: requests>=2.31 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kunal kakara\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\kunal kakara\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\kunal kakara\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kunal kakara\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3)

# %%
df_tesla=yfin.download(tickers='TSLA', period='5y', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-27   20.118668   21.086666   20.036667   20.982668   20.982668
# 2019-02-28   21.261333   21.333332   20.720667   21.325333   21.325333
# 2019-03-01   20.462667   20.475332   19.459999   19.652666   19.652666
# 2019-03-04   19.874666   19.933332   18.851999   19.024000   19.024000
# 2019-03-05   18.799999   18.933332   18.006666   18.436001   18.436001
# ...                ...         ...         ...         ...         ...
# 2024-02-20  196.130005  198.600006  189.130005  193.759995  193.759995
# 2024-02-21  193.360001  199.440002  191.949997  194.770004  194.770004
# 2024-02-22  194.000000  198.320007  191.360001  197.410004  197.410004
# 2024-02-23  195.309998  197.570007  191.500000  191.970001  191.970001
# 2024-02-26  192.289993  201.779999  192.000000  199.399994  199.399994
#
#                Volume
# Date
# 2019-02-27  167758500
# 2019-02-28  157810500
# 2019-03-01  343671000
# 2019-03-04  256452000
# 2019-03-05  281470500
# ...               ...
# 2024-02-20  104545800
# 2024-02-21  103844000
# 2024-02-22   92739500
# 2024-02-23   78670300
# 2024-02-26  111296200
#
# [1258 rows x 6 columns]

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-20  196.130005  198.600006  189.130005  193.759995  193.759995
# 2024-02-21  193.360001  199.440002  191.949997  194.770004  194.770004
# 2024-02-22  194.000000  198.320007  191.360001  197.410004  197.410004
# 2024-02-23  195.309998  197.570007  191.500000  191.970001  191.970001
# 2024-02-26  192.289993  201.779999  192.000000  199.399994  199.399994
#
#                Volume
# Date
# 2024-02-20  104545800
# 2024-02-21  103844000
# 2024-02-22   92739500
# 2024-02-23   78670300
# 2024-02-26  111296200

# %%
plt.figure(figsize=(12,4))
df_tesla['High'].plot()
plt.show()

# %%
#x limit and y limit

df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],c='green',figsize=(12,4))
plt.show()

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2019-02-27', '2019-02-28', '2019-03-01', '2019-03-04',
#                '2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08',
#                '2019-03-11', '2019-03-12',
#                ...
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-20', '2024-02-21', '2024-02-22',
#                '2024-02-23', '2024-02-26'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
shareprice_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']
shareprice_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
axis=plt.subplot()
axis.plot(index,shareprice_open)
plt.show()

# %% [markdown]
# # Date Time Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2019-02-27
# 1      2019-02-28
# 2      2019-03-01
# 3      2019-03-04
# 4      2019-03-05
#           ...
# 1253   2024-02-20
# 1254   2024-02-21
# 1255   2024-02-22
# 1256   2024-02-23
# 1257   2024-02-26
# Name: Date, Length: 1258, dtype: datetime64[ns]

# %%
df_tesla=df_tesla.set_index('Date',drop=True)
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-27   20.118668   21.086666   20.036667   20.982668   20.982668
# 2019-02-28   21.261333   21.333332   20.720667   21.325333   21.325333
# 2019-03-01   20.462667   20.475332   19.459999   19.652666   19.652666
# 2019-03-04   19.874666   19.933332   18.851999   19.024000   19.024000
# 2019-03-05   18.799999   18.933332   18.006666   18.436001   18.436001
# ...                ...         ...         ...         ...         ...
# 2024-02-20  196.130005  198.600006  189.130005  193.759995  193.759995
# 2024-02-21  193.360001  199.440002  191.949997  194.770004  194.770004
# 2024-02-22  194.000000  198.320007  191.360001  197.410004  197.410004
# 2024-02-23  195.309998  197.570007  191.500000  191.970001  191.970001
# 2024-02-26  192.289993  201.779999  192.000000  199.399994  199.399994
#
#                Volume
# Date
# 2019-02-27  167758500
# 2019-02-28  157810500
# 2019-03-01  343671000
# 2019-03-04  256452000
# 2019-03-05  281470500
# ...               ...
# 2024-02-20  104545800
# 2024-02-21  103844000
# 2024-02-22   92739500
# 2024-02-23   78670300
# 2024-02-26  111296200
#
# [1258 rows x 6 columns]

# %% [markdown]
# # Resampling

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  110.349998  116.269997  108.239998  109.099998  109.099998
# 2023-12-31  103.000000  111.750000  101.809998  108.099998  108.099998
# 2024-12-31  177.210007  184.679993  175.009995  181.059998  181.059998
#
#               Volume
# Date
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  41864700
# 2023-12-31  65125200
# 2024-12-31  78670300

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
# 2023-12-31  296.040009  299.290009  289.519989  293.339996  293.339996
# 2024-12-31  250.080002  251.250000  244.410004  248.419998  248.419998
#
#                Volume
# Date
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-31  221923300
# 2023-12-31  306590600
# 2024-12-31  198076800

# %%
df_tesla.resample(rule='A').max()['Open'].plot()
plt.show()

# %%
df_tesla.resample(rule='QS').max()['High'].plot()
plt.show()

# %%
df_tesla.resample(rule='BA').max()['High'].plot()
plt.show()

# %%
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12,4))
df_tesla['Open'].resample(rule='M').max()
df_tesla['Open'].resample(rule='M').max().plot(kind='bar')
plt.show()

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2019-02-27          NaN
# 2019-02-28          NaN
# 2019-03-01          NaN
# 2019-03-04          NaN
# 2019-03-05          NaN
# 2019-03-06          NaN
# 2019-03-07          NaN
# 2019-03-08          NaN
# 2019-03-11          NaN
# 2019-03-12    19.717199
# 2019-03-13    19.555133
# 2019-03-14    19.391066
# 2019-03-15    19.235000
# 2019-03-18    19.095333
# 2019-03-19    19.024000
# 2019-03-20    18.980400
# 2019-03-21    18.925400
# 2019-03-22    18.840133
# 2019-03-25    18.652800
# 2019-03-26    18.534067
# Name: High, dtype: float64

# %%
df_tesla['open:30 Days rolling']=df_tesla['Open'].rolling(30).mean()
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-27   20.118668   21.086666   20.036667   20.982668   20.982668
# 2019-02-28   21.261333   21.333332   20.720667   21.325333   21.325333
# 2019-03-01   20.462667   20.475332   19.459999   19.652666   19.652666
# 2019-03-04   19.874666   19.933332   18.851999   19.024000   19.024000
# 2019-03-05   18.799999   18.933332   18.006666   18.436001   18.436001
# ...                ...         ...         ...         ...         ...
# 2024-02-20  196.130005  198.600006  189.130005  193.759995  193.759995
# 2024-02-21  193.360001  199.440002  191.949997  194.770004  194.770004
# 2024-02-22  194.000000  198.320007  191.360001  197.410004  197.410004
# 2024-02-23  195.309998  197.570007  191.500000  191.970001  191.970001
# 2024-02-26  192.289993  201.779999  192.000000  199.399994  199.399994
#
#                Volume  open:30 Days rolling
# Date
# 2019-02-27  167758500                   NaN
# 2019-02-28  157810500                   NaN
# 2019-03-01  343671000                   NaN
# 2019-03-04  256452000                   NaN
# 2019-03-05  281470500                   NaN
# ...               ...                   ...
# 2024-02-20  104545800            201.551668
# 2024-02-21  103844000            200.125668
# 2024-02-22   92739500            198.655334
# 2024-02-23   78670300            197.329001
# 2024-02-26  111296200            196.053000
#
# [1258 rows x 7 columns]

# %%
df_tesla[['Open','open:30 Days rolling']].plot(figsize=(12,4))
plt.show()
